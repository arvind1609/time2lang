# %%
import pandas as pd
import numpy as np
import torch
import joblib
import sys 
import os
import argparse
sys.path.append("../time2lang/models")

from tqdm import tqdm
from chronos import ChronosPipeline
from utils import save_model, dictionary_to_arrays_numpy, zscore_sample_wise, zscore, apply_sss
from resnet import ResNet1D, ResNet1Dv2
from llama import CustomLlamaForCausalLM
from projection import ProjectionModel, ProjectionModelRes
from torch import nn
from datetime import datetime
from sklearn.metrics import balanced_accuracy_score
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder
from transformers.models.llama import LlamaForCausalLM
from transformers import pipeline, AutoTokenizer
from itertools import chain

# %% [markdown]
# ## (a) Load the required models

# %%
device = "cuda:2" if torch.cuda.is_available() else "cpu"

resnet = ResNet1Dv2(in_channels=768,
                 base_filters=32,
                 kernel_size=3,
                 stride=2,
                 n_block=6,
                 groups=1,
                 n_classes=999).to(device) # n_classes does not matter

chronos = ChronosPipeline.from_pretrained(
    "amazon/chronos-t5-base",
    device_map=device,
    torch_dtype=torch.float32,
)

n_classes = 6 # 6 periodicity classes

model_id = "meta-llama/Llama-3.2-1B"
llama = CustomLlamaForCausalLM.from_pretrained(model_id).to(device)
projection = ProjectionModelRes(n_classes=n_classes).to(device)

resnet.load_state_dict(torch.load("weights/resnet.pt", weights_only=True))
projection.load_state_dict(torch.load("weights/proj.pt", weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## (b) Extract features

# %% [markdown]
# There three important functions for feature extraction:
#
# - `hook_linear`: Creates a hook to extract features from the corresponding layer (linear_2 in our case)
# - `feature_extraction`: Given a time series, we apply a forward pass and extract the features using the hook
# - `extract_all_features`: Helper function to loop over a dataset for feature extraction

# %%
features = []
def hook_linear(module, input, output):
    features.append(output)

def feature_extraction(resnet, chronos, llama, projection, ts, use_residual):
    
    resnet.eval()
    chronos.model.eval()
    llama.model.eval()
    projection.eval()

    global features
    features = []  
    hook = projection.linear_2[0].register_forward_hook(hook_linear)

    with torch.inference_mode():
        chronos_embeddings = chronos.embed(ts)[0].permute(0, 2, 1).to(device) # swap context and ts length dimensions
        resnet_embeddings = resnet(chronos_embeddings).permute(0, 2, 1)
        pad_embeddings = torch.nn.functional.pad(resnet_embeddings, (0, 2048 - resnet_embeddings.shape[-1])) # shape = (batch_size, context based on kernel, features)
        llama_embeddings = llama(inputs_embeds=pad_embeddings) # llama embedding shape = (batch_size, context based on kernel, features)
        if use_residual:
            embeddings = projection(llama_embeddings.mean(dim=1), chronos_embeddings.mean(dim=-1))
        else:
            embeddings = projection(llama_embeddings.mean(dim=1), torch.zeros(chronos_embeddings.shape).mean(dim=-1).to(device)) # we simply add 0-tensor if we do not use residual
    hook.remove()
    return features[0]

# %%
def extract_all_features(X, use_residual=False):
    all_feats = []
    for ts in tqdm(X):
        ts = torch.tensor(zscore(ts))
        all_feats.append(feature_extraction(resnet, chronos, llama, projection, ts, use_residual).cpu().numpy())
    return all_feats

# %% [markdown]
# #### Example feature extraction
# - We are given a 2D array `X` of shape `(100, 1000)`
# - The extracted features are of shape `(100, 256)`
# - These features can be used to classification or regression using traditional ML methods

# %%
X = np.random.rand(100, 1000)
print(X.shape)
# Out:
# (100, 1000)

# %%
features = extract_all_features(X)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 14.62it/s]

# %%
print(np.vstack(features).shape)
# Out:
# (100, 256)

# %% [markdown]
# ## (c) StudentLife
#
# An example of feature extraction from time2lang and classifying the conversation embeddings into flourishing using a random forest.

# %%
train = joblib.load(f"../time2lang/data/studentlife/train.p")
test = joblib.load(f"../time2lang/data/studentlife/test.p")

# %%
X_train = np.vstack(extract_all_features(train['features'], use_residual=False))
y_train = train['labels']
X_test = np.vstack(extract_all_features(test['features'], use_residual=False))
y_test= test['labels']
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 36/36 [00:01<00:00, 19.44it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 19.43it/s]

# %%
print(f"Training data: {X_train.shape} | {y_train.shape}")
print(f"Test data: {X_test.shape} | {y_test.shape}")
# Out:
# Training data: (36, 256) | (36,)
# Test data: (10, 256) | (10,)

# %%
# Training 5 different splits and testing on the hold-out set
auroc_avg, auprc_avg = apply_sss(X_train=X_train, 
                           y_train=y_train,
                           X_test=X_test,
                           y_test=y_test,
                           backbone='rf')
# Out:
# ------ Running split 1 -------
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# ------ Running split 2 -------
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# ------ Running split 3 -------
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# ------ Running split 4 -------
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# ------ Running split 5 -------
# Fitting 2 folds for each of 144 candidates, totalling 288 fits

# %%
print(f"AUROC: {np.mean(auroc_avg)} ({np.std(auroc_avg)})")
print(f"AUPRC: {np.mean(auprc_avg)} ({np.std(auprc_avg)})")
# Out:
# AUROC: 0.708 (0.09765244492586962)
# AUPRC: 0.7445555555555556 (0.10847428588337786)
# [CV 2/2; 27/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 27/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 55/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 55/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 1/2; 76/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 76/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 108/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 108/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 4/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 4/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 1/2; 46/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 46/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.250 total time=   0.1s
# [CV 1/2; 106/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 106/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.375 total time=   0.1s
# [CV 2/2; 106/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 106/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 22/144] START bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 22/144] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 1/2; 80/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 80/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 80/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 80/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 3/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 3/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 2/2; 36/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 36/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 64/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 64/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 131/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 131/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 141/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 141/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 1/2; 15/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 15/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 34/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 34/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.312 total time=   0.1s
# [CV 1/2; 79/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 79/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 79/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 79/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 121/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/2; 121/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 121/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 121/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 14/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 14/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 59/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 59/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 2/2; 81/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 81/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 100/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 100/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 133/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 133/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 2/2; 10/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 10/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 49/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 49/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 73/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/2; 73/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.312 total time=   0.0s
# [CV 2/2; 73/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 73/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 125/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 125/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.312 total time=   0.0s
# [CV 2/2; 125/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 125/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 1/2; 2/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 2/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 2/2; 52/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 52/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 116/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 116/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 2/2; 116/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 116/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 1/2; 32/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 32/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 86/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 86/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 86/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 86/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 8/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 8/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 47/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 47/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 1/2; 76/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 76/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 76/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 76/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 31/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 31/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 53/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 53/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 2/2; 73/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 73/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 2/2; 84/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 84/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 124/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 124/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 16/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 16/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 52/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 52/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.312 total time=   0.1s
# [CV 1/2; 110/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 110/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.312 total time=   0.1s
# [CV 2/2; 110/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 110/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 19/144] START bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 19/144] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.0s
# [CV 2/2; 40/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 40/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 88/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 88/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 2/2; 88/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 88/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 6/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 6/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 50/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 50/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 114/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 114/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 114/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 114/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 30/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 30/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 78/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 78/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 78/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 78/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 26/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 26/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 65/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 65/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 90/144] START bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 90/144] END bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 137/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 137/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 20/144] START bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 20/144] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.250 total time=   0.1s
# [CV 2/2; 63/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 63/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 98/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 98/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.375 total time=   0.1s
# [CV 2/2; 98/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 98/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 16/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 16/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 45/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 45/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 1/2; 72/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 72/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 72/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 72/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 25/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/2; 25/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.375 total time=   0.1s
# [CV 2/2; 44/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 44/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 107/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 107/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 107/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 107/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 2/2; 139/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 139/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 2/2; 11/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 11/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 33/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 33/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 47/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 47/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 1/2; 80/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 80/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 80/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 80/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 29/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 29/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 51/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 51/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 1/2; 75/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 75/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 2/2; 90/144] START bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 90/144] END bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 144/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 144/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 2/2; 32/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 32/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 69/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 69/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.250 total time=   0.1s
# [CV 2/2; 69/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 69/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 2/2; 133/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 133/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 143/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 143/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 2/2; 15/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 15/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 2/2; 39/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 39/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 1/2; 62/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 62/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 1/2; 127/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 127/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.0s
# [CV 2/2; 127/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 127/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 1/2; 8/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 8/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 51/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 51/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 81/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/2; 81/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 2/2; 81/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 81/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 1/2; 127/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 127/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 2/2; 127/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 127/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 1/2; 5/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 5/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 39/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 39/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 60/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 60/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 125/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 125/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 2/2; 125/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 125/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 27/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 27/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 2/2; 47/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 47/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 66/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 66/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 115/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 115/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 2/2; 144/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 144/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 32/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 32/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.250 total time=   0.1s
# [CV 2/2; 64/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 64/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 128/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 128/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.312 total time=   0.1s
# [CV 2/2; 128/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 128/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 26/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 26/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 1/2; 67/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 67/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.1s
# [CV 2/2; 67/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 67/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 133/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 133/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.688 total time=   0.0s
# [CV 1/2; 143/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 143/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.0s
# [CV 2/2; 17/144] START bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 17/144] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 1/2; 42/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 42/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 116/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 116/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 116/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 116/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 32/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 32/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 74/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 74/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 74/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 74/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 12/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 12/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 46/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 46/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 91/144] START bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 91/144] END bootstrap=False, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 1/2; 116/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 116/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 26/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 26/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 57/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/2; 57/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.312 total time=   0.1s
# [CV 1/2; 88/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 88/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.312 total time=   0.1s
# [CV 2/2; 88/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 88/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 7/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 7/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 1/2; 37/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 37/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 2/2; 59/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 59/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.1s
# [CV 1/2; 100/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 100/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 100/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 100/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 16/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 16/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 56/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 56/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 120/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 120/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 120/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 120/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 32/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 32/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 75/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 75/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 75/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 75/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 127/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 127/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 127/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 127/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 1/2; 26/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 26/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 1/2; 71/144] START bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 71/144] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 99/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 99/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 1/2; 115/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 115/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 2/2; 143/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 143/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 1/2; 22/144] START bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 22/144] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.250 total time=   0.1s
# [CV 2/2; 60/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 60/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 123/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 123/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.312 total time=   0.0s
# [CV 2/2; 123/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# ...
# [CV 1/2; 37/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 1/2; 60/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 60/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 119/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 119/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 2/2; 119/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 119/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 2/2; 10/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 10/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 52/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 52/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 118/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 118/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 118/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 118/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 1/2; 2/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 2/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 1/2; 44/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 44/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 82/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 82/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 123/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 123/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 1/2; 136/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 136/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.688 total time=   0.1s
# [CV 1/2; 27/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 27/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.250 total time=   0.0s
# [CV 1/2; 41/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/2; 41/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.250 total time=   0.1s
# [CV 1/2; 83/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 83/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.312 total time=   0.0s
# [CV 2/2; 83/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 83/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 2/2; 131/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 131/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 2/2; 139/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 139/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.750 total time=   0.1s
# [CV 2/2; 13/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 13/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 2/2; 38/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 38/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 1/2; 99/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 99/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.562 total time=   0.0s
# [CV 2/2; 99/144] START bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 99/144] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.0s
# [CV 2/2; 134/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 134/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 2/2; 14/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 14/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 54/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 54/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 118/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 118/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 118/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/2; 118/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 31/144] START bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 31/144] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 50/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 50/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 114/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 114/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 114/144] START bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 114/144] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 5/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 5/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 2/2; 35/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 35/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 1/2; 46/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/2; 46/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 87/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 87/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.0s
# [CV 1/2; 106/144] START bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/2; 106/144] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.750 total time=   0.1s
# [CV 1/2; 143/144] START bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/2; 143/144] END bootstrap=False, max_depth=50, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.688 total time=   0.0s
# [CV 2/2; 21/144] START bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 21/144] END bootstrap=True, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 2/2; 45/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 45/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.625 total time=   0.1s
# [CV 1/2; 76/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/2; 76/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.375 total time=   0.1s
# [CV 2/2; 76/144] START bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 76/144] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 3/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 3/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.625 total time=   0.0s
# [CV 2/2; 41/144] START bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/2; 41/144] END bootstrap=True, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 2/2; 64/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 64/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 2/2; 132/144] START bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/2; 132/144] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 10/144] START bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 10/144] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.562 total time=   0.1s
# [CV 1/2; 53/144] START bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/2; 53/144] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.562 total time=   0.1s
# [CV 1/2; 88/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/2; 88/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.1s
# [CV 2/2; 88/144] START bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/2; 88/144] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.625 total time=   0.1s
# [CV 2/2; 7/144] START bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/2; 7/144] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 37/144] START bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/2; 37/144] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.438 total time=   0.1s
# [CV 2/2; 58/144] START bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/2; 58/144] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.438 total time=   0.1s
# [CV 1/2; 123/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/2; 123/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 2/2; 123/144] START bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/2; 123/144] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.438 total time=   0.0s
